# %% [markdown]
# THE SPARKS FOUNDATION
#
# TASK3: Exploratory Data Analysis-Retail
#
# Dona Biju

# %%
#importing required libraries
import numpy as np
import pandas as pd

# %%
#Extracting the data
retail=pd.read_csv("SampleSuperstore.csv")
print("The data extracted successfully")
# Out:
# The data extracted successfully

# %%
retail
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#gives the first 5 values
retail.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#gives the last 5 values
retail.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
#shape of the data
retail.shape
# Out:
# (9994, 13)

# %%
#structure of data
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# Country         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Postal Code     9994 non-null int64
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#gives the statistical data
retail.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#to check if null values present
retail.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#gives the distinct values
retail.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#gives the count of unique value in Quantity
retail['Quantity'].value_counts()
# Out:
# 3     2409
# 2     2402
# 5     1230
# 4     1191
# 1      899
# 7      606
# 6      572
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      27
# 12      23
# Name: Quantity, dtype: int64

# %%
#gives the correlation of the data
retail.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.catplot(x="Category",y="Profit",data=retail,kind="bar",ci=None,col="Region")

# %%
sns.catplot(x="Segment",y="Profit",kind="bar",col="Region",ci=None,data=retail)

# %%
#histogram of the data
retail.hist(bins=60,figsize=(20,15))
plt.show()

# %%
sns.pairplot(retail,hue='Discount')
# Out:
# C:\Users\donabiju\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\donabiju\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.pairplot(retail)

# %%
fig=axes=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(retail.corr(),annot=True)
plt.show()

# %% [raw]
# Discount and Profit are Negatively Correlated
# Sales and Profit are  Moderately Correlated

# %%
fig=axes=plt.subplots(1,1,figsize=(12,7))
sns.countplot(retail["Quantity"],hue=retail["Region"])
plt.show()

# %%
retail1=retail['State'].value_counts()
retail1.head()
# Out:
# California      2001
# New York        1128
# Texas            985
# Pennsylvania     587
# Washington       506
# Name: State, dtype: int64

# %%
retail1.plot(kind='bar',figsize=(15,5))
plt.xlabel('Frequency')
plt.xlabel('States')
plt.title("State")
plt.show()

# %%
#lowest number of State
retail['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %% [raw]
# California, New York and Texas are the top 3 countries depending upon the frequency.

# %%
retail2=retail['Sales'].value_counts()
retail2.head()
# Out:
# 12.960    56
# 19.440    39
# 15.552    39
# 25.920    36
# 10.368    36
# Name: Sales, dtype: int64

# %%
sns.set(rc={'figure.figsize':(10,10)})
retail['Category'].value_counts().plot.pie()

# %% [raw]
# The Office Supplies have topped in sub-category followed by Furniture and Tecnology

# %%
sns.set(rc={'figure.figsize':(10,10)})
retail['Sub-Category'].value_counts().plot.pie()

# %%
sns.set(rc={'figure.figsize':(10,10)})
retail['Segment'].value_counts().plot.pie()
plt.legend()

# %% [raw]
# The Consumer segment is greater compared to Corporate and Home Office
